# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# guidedbackprop

# Define the labels for the subplots
rows = ['A', 'C', 'B', 'D']
cols = ['DenseNet121', 'MT_binGCS', 'MT_ordGCS']

# Define probabilities for each subplot
probabilities = {
    'A_DenseNet121': 0.54, 'A_MT_binGCS': 0.31, 'A_MT_ordGCS': 0.40,
    'B_DenseNet121': 0.57, 'B_MT_binGCS': 0.58, 'B_MT_ordGCS': 0.46,
    'C_DenseNet121': 0.61, 'C_MT_binGCS': 0.30, 'C_MT_ordGCS': 0.56,
    'D_DenseNet121': 0.58, 'D_MT_binGCS': 0.90, 'D_MT_ordGCS': 0.51
}

# Define the paths to the images (example paths, replace with your actual paths)
image_paths = {
    'A_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/34-label-GOOD_PROGNOSIS/34_slice_19_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'A_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/34-label-GOOD_PROGNOSIS/34_slice_19_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'A_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/34-label-GOOD_PROGNOSIS/34_slice_19_guidedBackProp-label-GOOD_PROGNOSIS.png',
    'B_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/93-label-GOOD_PROGNOSIS/93_slice_13_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'B_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/93-label-GOOD_PROGNOSIS/93_slice_13_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'B_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/93-label-GOOD_PROGNOSIS/93_slice_13_guidedBackProp-label-GOOD_PROGNOSIS.png',
    'C_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/59-label-POOR_PROGNOSIS/59_slice_13_guidedBackProp-label-POOR_PROGNOSIS.png', 
    'C_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/59-label-POOR_PROGNOSIS/59_slice_13_guidedBackProp-label-POOR_PROGNOSIS.png', 
    'C_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/59-label-POOR_PROGNOSIS/59_slice_13_guidedBackProp-label-POOR_PROGNOSIS.png',
    'D_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/140-label-POOR_PROGNOSIS/140_slice_15_guidedBackProp-label-POOR_PROGNOSIS.png', 
    'D_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/140-label-POOR_PROGNOSIS/140_slice_15_guidedBackProp-label-POOR_PROGNOSIS.png', 
    'D_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/140-label-POOR_PROGNOSIS/140_slice_15_guidedBackProp-label-POOR_PROGNOSIS.png'
}

# Create a figure and axes with a black background
fig, axes = plt.subplots(nrows=2, ncols=6, figsize=(12.8, 4), constrained_layout=True)#, facecolor='black', gridspec_kw={'wspace': 0.05, 'hspace': 0.05})

# Define the order of rows to match the desired layout
row_order = ['A', 'B', 'C', 'D']

# Loop through each subplot to set images, labels, probabilities, and remove the axis
for idx, row in enumerate(row_order):
    for j, col in enumerate(cols):
        ax = axes[idx // 2, j + (3 if idx % 2 else 0)]
        label = f'{row}_{col.replace(" ", "_").replace("(", "").replace(")", "").replace(".", "")}'
        prob = probabilities[label]
        img_path = image_paths[label]
        img = mpimg.imread(img_path)  # Load the corresponding image
        
        ax.imshow(img)  # Display the image
        ax.text(0.5, 0.9, f'$p = {prob:.2f}$', horizontalalignment='center', verticalalignment='center', fontsize=10, color='white', backgroundcolor='black', transform=ax.transAxes)
        ax.set_axis_off()

# Set column titles for the first row, specific for each subplot
titles=['DenseNet121', 'MT (bin GCS, bin age)', 'MT (ord GCS, bin age)', 'DenseNet121', 'MT (bin GCS, bin age)', 'MT (ord GCS, bin age)']
for j, title in enumerate(titles):
    axes[0, j].set_title(title, fontsize=12, color='black')

# Add annotations for A, B, C, D
fig.text(0.000001, 0.73, 'A', fontsize=18, color='black', weight='bold', ha='center', va='center')
fig.text(0.000001, 0.25, 'C', fontsize=18, color='black', weight='bold', ha='center', va='center')
fig.text(0.5, 0.73, 'B', fontsize=18, color='black', weight='bold', ha='center', va='center')
fig.text(0.5, 0.25, 'D', fontsize=18, color='black', weight='bold', ha='center', va='center')

# Adjust layout
# plt.tight_layout(rect=[0.02, 0.03, 1, 0.9])

# Save and show the plot
plt.savefig('/home/ubuntu/tenerife/miriam/ICH_Prog_MultiTaskLearning/printFigures/Figure3_SM_guidedBackProp.pdf', bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# guided grad cam

# Define the labels for the subplots
rows = ['A', 'B', 'C', 'D']
cols = ['DenseNet121', 'MT_binGCS', 'MT_ordGCS']

# Define probabilities for each subplot
probabilities = {
    'A_DenseNet121': 0.54, 'A_MT_binGCS': 0.31, 'A_MT_ordGCS': 0.40,
    'B_DenseNet121': 0.57, 'B_MT_binGCS': 0.58, 'B_MT_ordGCS': 0.46,
    'C_DenseNet121': 0.61, 'C_MT_binGCS': 0.30, 'C_MT_ordGCS': 0.56,
    'D_DenseNet121': 0.58, 'D_MT_binGCS': 0.90, 'D_MT_ordGCS': 0.51
}

# Define the paths to the images (example paths, replace with your actual paths)
image_paths = {
    'A_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/Guided-Grad-Cam/34-label-GOOD_PROGNOSIS/34_slice_19_Guided-Grad-Cam-label-GOOD_PROGNOSIS.png', 
    'A_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/Guided-Grad-Cam/34-label-GOOD_PROGNOSIS/34_slice_19_Guided-Grad-Cam-label-GOOD_PROGNOSIS.png', 
    'A_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/Guided-Grad-Cam/34-label-GOOD_PROGNOSIS/34_slice_19_Guided-Grad-Cam-label-GOOD_PROGNOSIS.png',
    'B_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/Guided-Grad-Cam/93-label-GOOD_PROGNOSIS/93_slice_13_Guided-Grad-Cam-label-GOOD_PROGNOSIS.png', 
    'B_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/Guided-Grad-Cam/93-label-GOOD_PROGNOSIS/93_slice_13_Guided-Grad-Cam-label-GOOD_PROGNOSIS.png', 
    'B_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/Guided-Grad-Cam/93-label-GOOD_PROGNOSIS/93_slice_13_Guided-Grad-Cam-label-GOOD_PROGNOSIS.png',
    'C_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/Guided-Grad-Cam/59-label-POOR_PROGNOSIS/59_slice_13_Guided-Grad-Cam-label-POOR_PROGNOSIS.png', 
    'C_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/Guided-Grad-Cam/59-label-POOR_PROGNOSIS/59_slice_13_Guided-Grad-Cam-label-POOR_PROGNOSIS.png', 
    'C_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/Guided-Grad-Cam/59-label-POOR_PROGNOSIS/59_slice_13_Guided-Grad-Cam-label-POOR_PROGNOSIS.png',
    'D_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/Guided-Grad-Cam/140-label-POOR_PROGNOSIS/140_slice_15_Guided-Grad-Cam-label-POOR_PROGNOSIS.png', 
    'D_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/Guided-Grad-Cam/140-label-POOR_PROGNOSIS/140_slice_15_Guided-Grad-Cam-label-POOR_PROGNOSIS.png', 
    'D_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/Guided-Grad-Cam/140-label-POOR_PROGNOSIS/140_slice_15_Guided-Grad-Cam-label-POOR_PROGNOSIS.png'
}

# Create a figure and axes with a black background
fig, axes = plt.subplots(nrows=2, ncols=6, figsize=(12.8, 4), constrained_layout=True)#, facecolor='black', gridspec_kw={'wspace': 0.05, 'hspace': 0.05})

# Define the order of rows to match the desired layout
row_order = ['A', 'B', 'C', 'D']

# Loop through each subplot to set images, labels, probabilities, and remove the axis
for idx, row in enumerate(row_order):
    for j, col in enumerate(cols):
        ax = axes[idx // 2, j + (3 if idx % 2 else 0)]
        label = f'{row}_{col.replace(" ", "_").replace("(", "").replace(")", "").replace(".", "")}'
        prob = probabilities[label]
        img_path = image_paths[label]
        img = mpimg.imread(img_path)  # Load the corresponding image
        
        ax.imshow(img)  # Display the image
        ax.text(0.5, 0.9, f'$p = {prob:.2f}$', horizontalalignment='center', verticalalignment='center', fontsize=10, color='white', backgroundcolor='black', transform=ax.transAxes)
        ax.set_axis_off()

# Set column titles for the first row, specific for each subplot
titles=['DenseNet121', 'MT (bin GCS, bin age)', 'MT (ord GCS, bin age)', 'DenseNet121', 'MT (bin GCS, bin age)', 'MT (ord GCS, bin age)']
for j, title in enumerate(titles):
    axes[0, j].set_title(title, fontsize=12, color='black')

# Add annotations for A, B, C, D
fig.text(0.000001, 0.73, 'A', fontsize=18, color='black', weight='bold', ha='center', va='center')
fig.text(0.000001, 0.25, 'C', fontsize=18, color='black', weight='bold', ha='center', va='center')
fig.text(0.5, 0.73, 'B', fontsize=18, color='black', weight='bold', ha='center', va='center')
fig.text(0.5, 0.25, 'D', fontsize=18, color='black', weight='bold', ha='center', va='center')

# Adjust layout
# plt.tight_layout(rect=[0.02, 0.03, 1, 0.9])

# Save and show the plot
plt.savefig('/home/ubuntu/tenerife/miriam/ICH_Prog_MultiTaskLearning/printFigures/SupFig1_SM_guidedGradCam.pdf', bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the labels for the subplots
rows = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
cols = ['DenseNet121', 'MT_binGCS', 'MT_ordGCS']

# Define probabilities for each subplot
probabilities = {
    'A_DenseNet121': 0.47, 'A_MT_binGCS': 0.65, 'A_MT_ordGCS': 0.36,
    'B_DenseNet121': 0.56, 'B_MT_binGCS': 0.30, 'B_MT_ordGCS': 0.46,
    'C_DenseNet121': 0.62, 'C_MT_binGCS': 0.08, 'C_MT_ordGCS': 0.63,
    'D_DenseNet121': 0.57, 'D_MT_binGCS': 0.44, 'D_MT_ordGCS': 0.39,
    'E_DenseNet121': 0.54, 'E_MT_binGCS': 0.36, 'E_MT_ordGCS': 0.46,
    'F_DenseNet121': 0.53, 'F_MT_binGCS': 0.22, 'F_MT_ordGCS': 0.41,
    'G_DenseNet121': 0.58, 'G_MT_binGCS': 0.38, 'G_MT_ordGCS': 0.47,
    'H_DenseNet121': 0.61, 'H_MT_binGCS': 0.59, 'H_MT_ordGCS': 0.56,
    'I_DenseNet121': 0.49, 'I_MT_binGCS': 0.48, 'I_MT_ordGCS': 0.37,
    'J_DenseNet121': 0.96, 'J_MT_binGCS': 0.65, 'J_MT_ordGCS': 0.91,
    'K_DenseNet121': 0.67, 'K_MT_binGCS': 0.91, 'K_MT_ordGCS': 0.67,
    'L_DenseNet121': 0.76, 'L_MT_binGCS': 0.94, 'L_MT_ordGCS': 0.81
}

# Define the paths to the images (example paths, replace with your actual paths)
image_paths = {
    'A_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/51-label-GOOD_PROGNOSIS/51_slice_23_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'A_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/51-label-GOOD_PROGNOSIS/51_slice_23_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'A_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/51-label-GOOD_PROGNOSIS/51_slice_23_guidedBackProp-label-GOOD_PROGNOSIS.png',
    'B_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/71-label-GOOD_PROGNOSIS/71_slice_25_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'B_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/71-label-GOOD_PROGNOSIS/71_slice_25_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'B_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/71-label-GOOD_PROGNOSIS/71_slice_25_guidedBackProp-label-GOOD_PROGNOSIS.png',
    'C_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/152-label-GOOD_PROGNOSIS/152_slice_19_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'C_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/152-label-GOOD_PROGNOSIS/152_slice_19_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'C_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/152-label-GOOD_PROGNOSIS/152_slice_19_guidedBackProp-label-GOOD_PROGNOSIS.png',
    'D_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/203-label-GOOD_PROGNOSIS/203_slice_18_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'D_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/203-label-GOOD_PROGNOSIS/203_slice_18_guidedBackProp-label-GOOD_PROGNOSIS.png', 
    'D_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/203-label-GOOD_PROGNOSIS/203_slice_18_guidedBackProp-label-GOOD_PROGNOSIS.png',
    'E_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/12-label-POOR_PROGNOSIS/12_slice_17_guidedBackProp-label-POOR_PROGNOSIS.png', 
    'E_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/12-label-POOR_PROGNOSIS/12_slice_17_guidedBackProp-label-POOR_PROGNOSIS.png', 
    'E_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/12-label-POOR_PROGNOSIS/12_slice_17_guidedBackProp-label-POOR_PROGNOSIS.png',
    'F_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/20-label-POOR_PROGNOSIS/20_slice_27_guidedBackProp-label-POOR_PROGNOSIS.png', 
    'F_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/20-label-POOR_PROGNOSIS/20_slice_27_guidedBackProp-label-POOR_PROGNOSIS.png', 
    'F_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/20-label-POOR_PROGNOSIS/20_slice_27_guidedBackProp-label-POOR_PROGNOSIS.png',
    'G_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/56-label-POOR_PROGNOSIS/56_slice_17_guidedBackProp-label-POOR_PROGNOSIS.png',
    'G_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/56-label-POOR_PROGNOSIS/56_slice_17_guidedBackProp-label-POOR_PROGNOSIS.png',
    'G_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/56-label-POOR_PROGNOSIS/56_slice_17_guidedBackProp-label-POOR_PROGNOSIS.png',
    'H_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/106-label-POOR_PROGNOSIS/106_slice_21_guidedBackProp-label-POOR_PROGNOSIS.png',
    'H_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/106-label-POOR_PROGNOSIS/106_slice_21_guidedBackProp-label-POOR_PROGNOSIS.png',
    'H_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/106-label-POOR_PROGNOSIS/106_slice_21_guidedBackProp-label-POOR_PROGNOSIS.png',
    'I_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/128-label-POOR_PROGNOSIS/128_slice_23_guidedBackProp-label-POOR_PROGNOSIS.png',
    'I_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/128-label-POOR_PROGNOSIS/128_slice_23_guidedBackProp-label-POOR_PROGNOSIS.png',
    'I_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/128-label-POOR_PROGNOSIS/128_slice_23_guidedBackProp-label-POOR_PROGNOSIS.png',
    'J_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/170-label-POOR_PROGNOSIS/170_slice_15_guidedBackProp-label-POOR_PROGNOSIS.png',
    'J_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/170-label-POOR_PROGNOSIS/170_slice_15_guidedBackProp-label-POOR_PROGNOSIS.png',
    'J_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/170-label-POOR_PROGNOSIS/170_slice_15_guidedBackProp-label-POOR_PROGNOSIS.png',
    'K_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/197-label-POOR_PROGNOSIS/197_slice_15_guidedBackProp-label-POOR_PROGNOSIS.png',
    'K_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/197-label-POOR_PROGNOSIS/197_slice_15_guidedBackProp-label-POOR_PROGNOSIS.png',
    'K_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/197-label-POOR_PROGNOSIS/197_slice_15_guidedBackProp-label-POOR_PROGNOSIS.png',
    'L_DenseNet121': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BaselineDenseNet_Prognosis/Dropout0.2WeightDecay0.0001/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/258-label-POOR_PROGNOSIS/258_slice_21_guidedBackProp-label-POOR_PROGNOSIS.png',
    'L_MT_binGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/BinaryGCS_BinaryAge_Prognosis_SAME_LOSS_PARAM/SaliencyMapsPrognosis/png_MedCam_th0.6/guidedBackProp/258-label-POOR_PROGNOSIS/258_slice_21_guidedBackProp-label-POOR_PROGNOSIS.png',
    'L_MT_ordGCS': '/home/ubuntu/tenerife/data/ZZ_ICH_PrognosisMICCAI/Results/ThreeClassGCS_BinaryAge_Prognosis_SameHP/SaliencyMapsPrognosis/png_MedCam/guidedBackProp/258-label-POOR_PROGNOSIS/258_slice_21_guidedBackProp-label-POOR_PROGNOSIS.png'
}

# Create a figure and axes
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(12.8, 12), constrained_layout=True)

# Define the order of rows to match the desired layout
row_order = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']

# Loop through each subplot to set images, labels, probabilities, and remove the axis
for idx, row in enumerate(row_order):
    for j, col in enumerate(cols):
        ax = axes[idx // 2, j + (3 if idx % 2 else 0)]
        label = f'{row}_{col.replace(" ", "_").replace("(", "").replace(")", "").replace(".", "")}'
        prob = probabilities[label]
        img_path = image_paths[label]
        img = mpimg.imread(img_path)  # Load the corresponding image
        
        ax.imshow(img)  # Display the image
        ax.text(0.5, 0.9, f'$p = {prob:.2f}$', horizontalalignment='center', verticalalignment='center', fontsize=10, color='white', backgroundcolor='black', transform=ax.transAxes)
        ax.set_axis_off()

# Set column titles for the first row, specific for each subplot
titles=['DenseNet121', 'MT (bin GCS, bin age)', 'MT (ord GCS, bin age)', 'DenseNet121', 'MT (bin GCS, bin age)', 'MT (ord GCS, bin age)']
for j, title in enumerate(titles):
    axes[0, j].set_title(title, fontsize=12, color='black')

# Add annotations for A, B, C, D, E, F, G, H, I, J, K, L
for idx, label in enumerate(row_order):
    y_pos = 1 - (idx // 2) * (1 / 6) - 0.08  # Adjusting y position based on row index for consistency
    if idx % 2 == 0:  # Annotation for column 1
        fig.text(0.000001, y_pos, label, fontsize=18, color='black', weight='bold', ha='center', va='center')
    else:  # Annotation for column 4
        fig.text(0.5, y_pos, label, fontsize=18, color='black', weight='bold', ha='center', va='center')


# Adjust layout
# plt.tight_layout(rect=[0.02, 0.03, 1, 0.9])

# Save and show the plot
plt.savefig('/home/ubuntu/tenerife/miriam/ICH_Prog_MultiTaskLearning/printFigures/SupFig3_Extra_guidedBackProp.pdf', bbox_inches="tight")
plt.show()
